# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Kiritiladigan rasm o‘lchami (masalan: 64x64)
input_shape = (64, 64, 3)

inputs = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Yosh uchun chiqish (regression)
age_output = Dense(1, name='age_output')(x)

# Jins uchun chiqish (binary classification)
gender_output = Dense(1, activation='sigmoid', name='gender_output')(x)

model = Model(inputs=inputs, outputs=[age_output, gender_output])

# %%
model.compile(
    optimizer='adam',
    loss={
        'age_output': 'mse',             # Yosh uchun: mean squared error
        'gender_output': 'binary_crossentropy'  # Jins uchun: binary classification
    },
    metrics={
        'age_output': 'mae',
        'gender_output': 'accuracy'
    }
)

# %%
import numpy as np

# 1000 ta sun’iy rasm (64x64 RGB)
X = np.random.rand(1000, 64, 64, 3)

# Har biri uchun yosh (0–100 orasida)
y_age = np.random.randint(0, 100, size=(1000,))

# Har biri uchun jins (0 yoki 1)
y_gender = np.random.randint(0, 2, size=(1000,))

# %%
model.fit(
    X, {'age_output': y_age, 'gender_output': y_gender},
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - age_output_loss: 1634.3849 - age_output_mae: 33.2155 - gender_output_accuracy: 0.5624 - gender_output_loss: 2.1493 - loss: 1636.5342 - val_age_output_loss: 780.0610 - val_age_output_mae: 24.4610 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.8176 - val_loss: 805.5872
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - age_output_loss: 993.3606 - age_output_mae: 27.3620 - gender_output_accuracy: 0.5366 - gender_output_loss: 2.6068 - loss: 995.9674 - val_age_output_loss: 821.5713 - val_age_output_mae: 24.9925 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.8919 - val_loss: 856.0931
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - age_output_loss: 974.1299 - age_output_mae: 26.2801 - gender_output_accuracy: 0.4983 - gender_output_loss: 2.3901 - loss: 976.5201 - val_age_output_loss: 789.3643 - val_age_output_mae: 24.5416 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.7326 - val_loss: 812.2662
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - age_output_loss: 972.9323 - age_output_mae: 26.7595 - gender_output_accuracy: 0.4920 - gender_output_loss: 2.6237 - loss: 975.5560 - val_age_output_loss: 783.0516 - val_age_output_mae: 24.5023 - val_gender_output_accuracy: 0.5200 - val_gender_output_loss: 0.6925 - val_loss: 812.1656
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 227ms/step - age_output_loss: 934.8765 - age_output_mae: 26.3410 - gender_output_accuracy: 0.4940 - gender_output_loss: 2.4127 - loss: 937.2891 - val_age_output_loss: 833.8257 - val_age_output_mae: 25.1293 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.7174 - val_loss: 869.1358
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - age_output_loss: 998.7487 - age_output_mae: 27.1625 - gender_output_accuracy: 0.4808 - gender_output_loss: 2.1098 - loss: 1000.8586 - val_age_output_loss: 783.9772 - val_age_output_mae: 24.5015 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.6998 - val_loss: 807.8441
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - age_output_loss: 940.0862 - age_output_mae: 26.1224 - gender_output_accuracy: 0.4825 - gender_output_loss: 2.2784 - loss: 942.3646 - val_age_output_loss: 791.3398 - val_age_output_mae: 24.6112 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.7825 - val_loss: 822.1351
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 175ms/step - age_output_loss: 911.9482 - age_output_mae: 25.8266 - gender_output_accuracy: 0.4926 - gender_output_loss: 2.0190 - loss: 913.9671 - val_age_output_loss: 799.1785 - val_age_output_mae: 24.7086 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.7195 - val_loss: 830.9855
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 228ms/step - age_output_loss: 967.2188 - age_output_mae: 26.7473 - gender_output_accuracy: 0.5095 - gender_output_loss: 1.5024 - loss: 968.7212 - val_age_output_loss: 778.3141 - val_age_output_mae: 24.4289 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.7202 - val_loss: 805.0895
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - age_output_loss: 913.3652 - age_output_mae: 26.0015 - gender_output_accuracy: 0.4739 - gender_output_loss: 1.6688 - loss: 915.0341 - val_age_output_loss: 793.2182 - val_age_output_mae: 24.6298 - val_gender_output_accuracy: 0.5650 - val_gender_output_loss: 0.6913 - val_loss: 824.0912

# %%
import numpy as np

# Sinov uchun bitta rasm (64x64x3)
test_image = np.random.rand(1, 64, 64, 3)  # yoki haqiqiy rasm

# Prognoz qilish
age_pred, gender_pred = model.predict(test_image)

print(f"Taxminiy yosh: {age_pred[0][0]:.1f}")
print("Jinsi:", "Ayol" if gender_pred[0][0] > 0.5 else "Erkak")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Taxminiy yosh: 45.6
# Jinsi: Ayol

# %%
model.save("yosh_jins_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy
from tensorflow.keras.metrics import MeanAbsoluteError, Accuracy

model.compile(
    optimizer='adam',
    loss={
        'age_output': MeanSquaredError(),
        'gender_output': BinaryCrossentropy()
    },
    metrics={
        'age_output': MeanAbsoluteError(),
        'gender_output': Accuracy()
    }
)

model.save("yosh_jins_model.h5")  # endi to‘g‘ri saqlanadi
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
