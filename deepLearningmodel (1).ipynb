# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Kiritiladigan rasm o‘lchami (masalan: 64x64)
input_shape = (64, 64, 3)

inputs = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)

# Yosh uchun chiqish (regression)
age_output = Dense(1, name='age_output')(x)

# Jins uchun chiqish (binary classification)
gender_output = Dense(1, activation='sigmoid', name='gender_output')(x)

model = Model(inputs=inputs, outputs=[age_output, gender_output])

# %%
model.compile(
    optimizer='adam',
    loss={
        'age_output': 'mse',             # Yosh uchun: mean squared error
        'gender_output': 'binary_crossentropy'  # Jins uchun: binary classification
    },
    metrics={
        'age_output': 'mae',
        'gender_output': 'accuracy'
    }
)

# %%
import numpy as np

# 1000 ta sun’iy rasm (64x64 RGB)
X = np.random.rand(1000, 64, 64, 3)

# Har biri uchun yosh (0–100 orasida)
y_age = np.random.randint(0, 100, size=(1000,))

# Har biri uchun jins (0 yoki 1)
y_gender = np.random.randint(0, 2, size=(1000,))

# %%
model.fit(
    X, {'age_output': y_age, 'gender_output': y_gender},
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - age_output_loss: 1628.2717 - age_output_mae: 32.8810 - gender_output_accuracy: 0.4677 - gender_output_loss: 7.2863 - loss: 1635.5582 - val_age_output_loss: 785.5952 - val_age_output_mae: 23.3411 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 4.6001 - val_loss: 774.3755
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 210ms/step - age_output_loss: 1004.1745 - age_output_mae: 27.3548 - gender_output_accuracy: 0.4885 - gender_output_loss: 4.5769 - loss: 1008.7514 - val_age_output_loss: 793.7965 - val_age_output_mae: 23.1518 - val_gender_output_accuracy: 0.4800 - val_gender_output_loss: 0.6922 - val_loss: 760.9124
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - age_output_loss: 968.2555 - age_output_mae: 26.7442 - gender_output_accuracy: 0.5304 - gender_output_loss: 3.8385 - loss: 972.0941 - val_age_output_loss: 814.3157 - val_age_output_mae: 23.2869 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.7760 - val_loss: 773.8791
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 182ms/step - age_output_loss: 1001.3892 - age_output_mae: 26.9216 - gender_output_accuracy: 0.4799 - gender_output_loss: 3.6714 - loss: 1005.0605 - val_age_output_loss: 793.9880 - val_age_output_mae: 23.1542 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.7126 - val_loss: 761.0493
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 238ms/step - age_output_loss: 941.0378 - age_output_mae: 26.0098 - gender_output_accuracy: 0.5089 - gender_output_loss: 3.4981 - loss: 944.5359 - val_age_output_loss: 785.7806 - val_age_output_mae: 23.1190 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.7205 - val_loss: 758.0856
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - age_output_loss: 903.0906 - age_output_mae: 25.7886 - gender_output_accuracy: 0.5158 - gender_output_loss: 3.0634 - loss: 906.1539 - val_age_output_loss: 820.0454 - val_age_output_mae: 24.1538 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.8135 - val_loss: 819.1741
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - age_output_loss: 914.3101 - age_output_mae: 25.9727 - gender_output_accuracy: 0.5238 - gender_output_loss: 2.6419 - loss: 916.9519 - val_age_output_loss: 783.4562 - val_age_output_mae: 23.2569 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.6929 - val_loss: 765.2721
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - age_output_loss: 884.8493 - age_output_mae: 25.3782 - gender_output_accuracy: 0.4851 - gender_output_loss: 2.8039 - loss: 887.6533 - val_age_output_loss: 850.0680 - val_age_output_mae: 24.6856 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.8437 - val_loss: 856.1628
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - age_output_loss: 951.0233 - age_output_mae: 26.3993 - gender_output_accuracy: 0.5125 - gender_output_loss: 2.4071 - loss: 953.4304 - val_age_output_loss: 844.5793 - val_age_output_mae: 24.5949 - val_gender_output_accuracy: 0.5050 - val_gender_output_loss: 0.7962 - val_loss: 849.5110
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - age_output_loss: 1013.8251 - age_output_mae: 27.1349 - gender_output_accuracy: 0.4946 - gender_output_loss: 2.4416 - loss: 1016.2667 - val_age_output_loss: 809.3654 - val_age_output_mae: 23.2539 - val_gender_output_accuracy: 0.4950 - val_gender_output_loss: 0.9514 - val_loss: 770.5834

# %%
import numpy as np

# Sinov uchun bitta rasm (64x64x3)
test_image = np.random.rand(1, 64, 64, 3)  # yoki haqiqiy rasm

# Prognoz qilish
age_pred, gender_pred = model.predict(test_image)

print(f"Taxminiy yosh: {age_pred[0][0]:.1f}")
print("Jinsi:", "Ayol" if gender_pred[0][0] > 0.5 else "Erkak")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Taxminiy yosh: 55.3
# Jinsi: Ayol

# %%
import keras
keras.saving.save_model(model, "yosh_jins_model.keras")
