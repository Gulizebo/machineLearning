# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Sample dataset: Predicting house price based on size
X = np.array([50, 75, 100, 45, 120, 80, 95, 110, 130]).reshape(-1, 1)
y = np.array([100000, 150000, 200000, 90000, 250000, 160000, 190000, 230000, 300000])

# %%
# Transform features for polynomial regression
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
# Train model
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Predictions
y_pred = model.predict(X_poly)

# %%
# Model evaluation
mse = mean_squared_error(y, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 26282336.83356532

# %%
# Visualization
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Polynomial Regression')
plt.xlabel('Size in Square Meters')
plt.ylabel('Price')
plt.title('Polynomial Regression Model for House Prices')
plt.legend()
plt.show()
